# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import datetime

# %% [markdown]
# ### Reading Data

# %%
df2020 = pd.read_excel('data_2020.xlsx')
df2021 = pd.read_excel('data_2021.xlsx')
df2022 = pd.read_excel('data_2022.xlsx',skiprows = 1)

# %% [markdown]
# ### PreProcessing

# %%
df2021 = df2021.drop(0).reset_index(drop=True)

# %%
df2020.columns = df2021.columns
df2022.columns = df2021.columns

# %%
df2020.head()
# Out:
#                   DATE      Time Temperature Dew Point Humidity Wind  \
# 0  2020-01-01 00:00:00  00:29:00       37 °F     32 °F     81 %   NW
# 1                  NaN  00:55:00       37 °F     32 °F     81 %    N
# 2                  NaN  01:25:00       37 °F     32 °F     81 %    N
# 3                  NaN  01:55:00       37 °F     32 °F     81 %    N
# 4                  NaN  02:25:00       37 °F     32 °F     81 %    N
#
#   Wind Speed Wind Gust  Pressure Precip. Condition
# 0      2 mph     0 mph  29.41 in  0.0 in       Fog
# 1      3 mph     0 mph  29.41 in  0.0 in       Fog
# 2      3 mph     0 mph  29.41 in  0.0 in       Fog
# 3      6 mph     0 mph  29.41 in  0.0 in       Fog
# 4      5 mph     0 mph  29.39 in  0.0 in       Fog

# %%
df2021.head()
# Out:
#                   DATE      Time Temperature Dew Point Humidity  Wind  \
# 0  2021-01-01 00:00:00  00:25:00       46 °F     43 °F     87 %  CALM
# 1  2021-01-01 00:00:00  00:55:00       45 °F     43 °F     93 %  CALM
# 2  2021-01-01 00:00:00  01:55:00       45 °F     39 °F     81 %  CALM
# 3  2021-01-01 00:00:00  03:25:00       41 °F     37 °F     87 %  CALM
# 4  2021-01-01 00:00:00  03:55:00       41 °F     36 °F     81 %  CALM
#
#   Wind Speed Wind Gust  Pressure Precip. Condition
# 0      0 mph     0 mph  29.24 in  0.0 in       Fog
# 1      0 mph     0 mph  29.24 in  0.0 in       Fog
# 2      0 mph     0 mph  29.24 in  0.0 in       Fog
# 3      0 mph     0 mph  29.24 in  0.0 in       Fog
# 4      0 mph     0 mph  29.24 in  0.0 in       Fog

# %%
df2022.head()
# Out:
#   DATE      Time Temperature Dew Point Humidity  Wind Wind Speed Wind Gust  \
# 0  NaN  00:25:00       52 °F     46 °F     82 %  CALM      0 mph     0 mph
# 1  NaN  00:55:00       52 °F     46 °F     82 %  CALM      0 mph     0 mph
# 2  NaN  01:25:00       52 °F     46 °F     82 %  CALM      0 mph     0 mph
# 3  NaN  01:55:00       50 °F     45 °F     82 %  CALM      0 mph     0 mph
# 4  NaN  02:25:00       50 °F     45 °F     82 %  CALM      0 mph     0 mph
#
#    Pressure Precip. Condition
# 0  29.41 in  0.0 in       Fog
# 1  29.39 in  0.0 in       Fog
# 2  29.39 in  0.0 in       Fog
# 3  29.39 in  0.0 in       Fog
# 4  29.39 in  0.0 in       Fog

# %%
def changeTypeDate(value):
    form = "%d/%m/%Y"
    try:
        return pd.to_datetime(value,errors = 'coerce',format =form)
    except:
        pd.NaT

df2022['DATE'] = df2022['DATE'].apply(changeType)
df2020['DATE'] = df2020['DATE'].apply(changeType)

# %%
l_date= str()
format = "%d/%m/%Y"
df2020['DATE'] = df2020['DATE'].fillna(0)
for index in range(0,len(df2020)):
    if df2020['DATE'][index]==0:
        df2020['DATE'][index] = datetime.datetime.strptime(l_date, format)
    else:
        l_date = df2020['DATE'][index].strftime(format)

# %%
last_date = '01/01/2022'
format = "%d/%m/%Y"
df2022['DATE'] = df2022['DATE'].fillna(0)
for index in range(0,len(df2022)):
    if df2022['DATE'][index]==0:
        df2022['DATE'][index] = datetime.datetime.strptime(last_date, format)
    else:
        last_date = df2022['DATE'][index].strftime(format)

# %%
df2022.head()
# Out:
#                   DATE      Time Temperature Dew Point Humidity  Wind  \
# 0  2022-01-01 00:00:00  00:25:00       52 °F     46 °F     82 %  CALM
# 1  2022-01-01 00:00:00  00:55:00       52 °F     46 °F     82 %  CALM
# 2  2022-01-01 00:00:00  01:25:00       52 °F     46 °F     82 %  CALM
# 3  2022-01-01 00:00:00  01:55:00       50 °F     45 °F     82 %  CALM
# 4  2022-01-01 00:00:00  02:25:00       50 °F     45 °F     82 %  CALM
#
#   Wind Speed Wind Gust  Pressure Precip. Condition
# 0      0 mph     0 mph  29.41 in  0.0 in       Fog
# 1      0 mph     0 mph  29.39 in  0.0 in       Fog
# 2      0 mph     0 mph  29.39 in  0.0 in       Fog
# 3      0 mph     0 mph  29.39 in  0.0 in       Fog
# 4      0 mph     0 mph  29.39 in  0.0 in       Fog

# %% [markdown]
# ### Dropping Na values that arent significant

# %%
df2020 = df2020['Time'].dropna()
df2021 = df2021['Time'].dropna()
df2022 = df2022['Time'].dropna()
len(df2022)
# Out:
# 17682

# %%
len(df2021)
# Out:
# 17579
